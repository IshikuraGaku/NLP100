# %%
import re
import json
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import re
import tqdm

# %matplotlib inline

# %%
df = pd.read_json("neko_dic.json", encoding="utf-8")

# %%
df = df.T

# %%
df
# Out:
#        surface    base         pos          pos1
# 0 0          一       一       名詞-数詞
# 2 0         吾輩     我が輩         代名詞
# 2 1          は       は      助詞-係助詞
# 2 2          猫       猫  名詞-普通名詞-一般
# 2 3          で       だ         助動詞  助動詞-ダ 連用形-一般
# ...        ...     ...         ...           ...
# 9960 7       ぬ       ず         助動詞  助動詞-ヌ 終止形-一般
# 9961 0  南無阿弥陀仏  南無阿弥陀仏  名詞-普通名詞-一般
# 9961 1  南無阿弥陀仏  南無阿弥陀仏  名詞-普通名詞-一般
# 9962 0   ありがたい    有り難い      形容詞-一般
# 9962 1   ありがたい    有り難い      形容詞-一般
#
# [186664 rows x 4 columns]

# %%
hist = df["base"].value_counts()
hist
# Out:
# の      10265
# だ       8134
# て       7905
# は       6514
# と       6163
#        ...
# ヒラキ        1
# 心労         1
# 雇婆         1
# 善意         1
# 嚢          1
# Name: base, Length: 10718, dtype: int64

# %%
hist_count = hist.value_counts()
hist_count
# Out:
# 1       4598
# 2       1798
# 3        903
# 4        531
# 5        433
#         ...
# 539        1
# 419        1
# 1623       1
# 243        1
# 259        1
# Name: base, Length: 233, dtype: int64

# %%
hist_sort = sorted(hist_count.items() ,key=lambda x:x)
hist_sort
# Out:
# [(1, 4598),
#  (2, 1798),
#  (3, 903),
#  (4, 531),
#  (5, 433),
#  (6, 303),
#  (7, 237),
#  (8, 172),
#  (9, 140),
#  (10, 118),
#  (11, 117),
#  (12, 97),
#  (13, 90),
#  (14, 85),
#  (15, 61),
#  (16, 67),
#  (17, 64),
#  (18, 48),
#  (19, 37),
#  (20, 51),
#  (21, 31),
#  (22, 27),
#  (23, 25),
#  (24, 22),
#  (25, 31),
#  (26, 15),
#  (27, 24),
#  (28, 19),
#  (29, 24),
#  (30, 24),
#  (31, 15),
#  (32, 21),
#  (33, 10),
#  (34, 12),
#  (35, 14),
#  (36, 14),
#  (37, 7),
#  (38, 13),
#  (39, 16),
#  (40, 15),
#  (41, 11),
#  (42, 7),
#  (43, 7),
#  (44, 5),
#  (45, 11),
#  (46, 6),
#  (47, 6),
#  (48, 11),
#  (49, 7),
#  (50, 3),
#  (51, 4),
#  (52, 7),
#  (53, 7),
#  (54, 12),
#  (55, 7),
#  (56, 4),
#  (57, 2),
#  (58, 4),
#  (59, 3),
#  (60, 2),
#  (61, 3),
#  (62, 2),
#  (63, 5),
#  (64, 2),
#  (65, 2),
#  (66, 4),
#  (67, 1),
#  (69, 1),
#  (70, 1),
#  (71, 2),
#  (72, 5),
#  (73, 3),
#  (74, 2),
#  (75, 1),
#  (76, 2),
#  (78, 4),
#  (79, 3),
#  (80, 1),
#  (81, 2),
#  (82, 2),
#  (83, 1),
#  (84, 2),
#  (85, 2),
#  (86, 2),
#  (88, 4),
#  (89, 3),
#  (90, 4),
#  (91, 2),
#  (93, 3),
#  (94, 2),
#  (95, 1),
#  (96, 2),
#  (97, 3),
#  (98, 2),
#  (100, 2),
#  (101, 2),
#  (103, 4),
#  (104, 5),
#  (105, 1),
#  (106, 1),
#  (107, 4),
#  (109, 1),
#  (110, 2),
#  (111, 2),
#  (114, 1),
#  (115, 2),
#  (117, 2),
#  (118, 1),
#  (120, 2),
#  (121, 1),
#  (122, 2),
#  (123, 2),
#  (125, 1),
#  (126, 4),
#  (127, 2),
#  (129, 1),
#  (131, 1),
#  (132, 1),
#  (133, 1),
#  (135, 1),
#  (136, 1),
#  (137, 1),
#  (138, 1),
#  (139, 1),
#  (140, 2),
#  (143, 1),
#  (148, 3),
#  (150, 1),
#  (151, 3),
#  (152, 2),
#  (153, 2),
#  (155, 1),
#  (156, 1),
#  (159, 1),
#  (161, 1),
#  (168, 2),
#  (172, 1),
#  (174, 1),
#  (175, 1),
#  (183, 1),
#  (186, 1),
#  (187, 1),
#  (190, 3),
#  (191, 1),
#  (196, 2),
#  (201, 1),
#  (203, 1),
#  (209, 1),
#  (210, 1),
#  (211, 1),
#  (212, 1),
#  (216, 1),
#  (217, 1),
#  (220, 2),
#  (225, 1),
#  (227, 1),
#  (231, 1),
#  (237, 2),
#  (238, 2),
#  (241, 1),
#  (243, 1),
#  (245, 1),
#  (256, 2),
#  (259, 1),
#  (261, 1),
#  (265, 2),
#  (270, 1),
#  (271, 1),
#  (274, 1),
#  (278, 2),
#  (279, 1),
#  (287, 1),
#  (298, 1),
#  (301, 1),
#  (306, 1),
#  (308, 1),
#  (314, 2),
#  (321, 1),
#  (324, 1),
#  (327, 1),
#  (330, 1),
#  (343, 1),
#  (383, 1),
#  (394, 1),
#  (396, 1),
#  (415, 1),
#  (419, 1),
#  (440, 1),
#  (448, 1),
#  (481, 1),
#  (488, 2),
#  (504, 1),
#  (513, 1),
#  (516, 2),
#  (539, 1),
#  (576, 1),
#  (618, 1),
#  (622, 1),
#  (666, 1),
#  (675, 1),
#  (694, 1),
#  (695, 1),
#  (708, 1),
#  (779, 1),
#  (849, 1),
#  (858, 1),
#  (934, 1),
#  (997, 1),
#  (1100, 1),
#  (1113, 1),
#  (1160, 1),
#  (1176, 1),
#  (1272, 1),
#  (1451, 1),
#  (1623, 1),
#  (1693, 1),
#  (1695, 1),
#  (1773, 1),
#  (2038, 1),
#  (2208, 1),
#  (2216, 1),
#  (2308, 1),
#  (3238, 1),
#  (3922, 1),
#  (4432, 1),
#  (5394, 1),
#  (5746, 1),
#  (6119, 1),
#  (6163, 1),
#  (6514, 1),
#  (7905, 1),
#  (8134, 1),
#  (10265, 1)]

# %%
left = [i[0] for i in hist_sort]
height = [i[1] for i in hist_sort]

# %%
plt.plot(left,height)
plt.xscale("log")
plt.yscale("log")
